# %% [markdown]
# # Grapths N = 8 Fidelity

# %%
name_architectures = [
    'Clements_Arct', 'ClementsBell_Arct',
    'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide_Arct', 'NEUROPULSBellCrossingSide2_Arct',]

# %% [markdown]
# ## Sweep PhaseChangers insertion loss
# IL=0dB \
# IMB=0dB \
# CT=-1000dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct',
    'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide_Arct', 'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, IMB=0.0, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'Clements_Arct',
    'Fldzhyan_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, IMB=0.0, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'ClementsBell_Arct',
    'FldzhyanBell_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide_Arct', 'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, IMB=0.0, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'ClementsBell_Arct',
    'FldzhyanBell_Arct',
    'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, IMB=0.0, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep PhaseChangers insertion loss
# IL=-0.5dB \
# IMB=-0.5dB \
# CT=-30dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct',
    'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide_Arct', 'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=-0.5, CT=-30.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'Clements_Arct',
    'Fldzhyan_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=-0.5, CT=-30.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'ClementsBell_Arct',
    'FldzhyanBell_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide_Arct', 'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=-0.5, CT=-30.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'ClementsBell_Arct',
    'FldzhyanBell_Arct',
    'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=-0.5, CT=-30.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep PhaseChangers insertion loss
# IL=-0.5dB \
# IMB=0.5dB \
# CT=-30dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct',
    'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide_Arct', 'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0.5, CT=-30.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'Clements_Arct',
    'Fldzhyan_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0.5, CT=-30.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'ClementsBell_Arct',
    'FldzhyanBell_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide_Arct', 'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0.5, CT=-30.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'ClementsBell_Arct',
    'FldzhyanBell_Arct',
    'NEUROPULSBell2_Arct',
    'NEUROPULSBellCrossingSide2_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240723_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0.5, CT=-30.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Sweep N
#
# PC_IL=-1.0dB \
# IL=-0.5dB \
# IMB=-0.5dB \
# CT=-30dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'Clements_Arct',
    'Fldzhyan_Arct',
    'NEUROPULS_Arct',
    'NEUROPULSCrossingSide_Arct',]


def filter_list_of_dicts(dict_list, PC_IL, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[0] == PC_IL and list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

ns = [4, 6, 8, 10, 12, 14, 16]

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    imbalances = []
    average = []
    std_dev = []
    for n in ns:
        file_JSON = "20240723_traking_"+arct+"_N"+str(n)+".json"
        with open(JSON_folder_name+file_JSON, 'r') as file:
            data = json.load(file)
        simulations = data["simulations"]
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, PC_IL=-1.0, IL=-0.5, IMB=-0.5, CT=-30.0)
        average.extend([sim["average"] for sim in filtered_list_disct])
        std_dev.extend([sim["std_dev"] for sim in filtered_list_disct])s
    plt.errorbar(ns, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('n')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240723_run_2_PCiloss/'
name_models_choise = [
    'Clements_Arct',
    'Fldzhyan_Arct',
    'NEUROPULS_Arct',
    'NEUROPULSCrossingSide_Arct',]


def filter_list_of_dicts(dict_list, PC_IL, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[0] == PC_IL and list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

ns = [4, 6, 8, 10, 12, 14, 16]

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    imbalances = []
    average = []
    std_dev = []
    for n in ns:
        file_JSON = "20240723_traking_"+arct+"_N"+str(n)+".json"
        with open(JSON_folder_name+file_JSON, 'r') as file:
            data = json.load(file)
        simulations = data["simulations"]
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, PC_IL=-1.0, IL=-0.5, IMB=0.5, CT=-30.0)
        average.extend([sim["average"] for sim in filtered_list_disct])
        std_dev.extend([sim["std_dev"] for sim in filtered_list_disct])
    plt.errorbar(ns, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('n')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()
