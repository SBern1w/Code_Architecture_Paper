# %% [markdown]
# # Grapths N = 8 Fidelity

# %% [markdown]
# ## Sweep PhaseChangers insertion loss - IL=0dB IMB=0dB CT=-1000dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240718/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBellCrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBellCrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240718_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, IMB=0.0, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240718/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'ClementsBell_Arct', 'FldzhyanBell_Arct',
    'NEUROPULSBell_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240718_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, IMB=0.0, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep PhaseChangers insertion loss - IL=0dB IMB=0dB NEUROPULS CT=-30dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240718/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBellCrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'ClementsBell_Arct', 'FldzhyanBell_Arct',
    'NEUROPULSBell_Arct']

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240718_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0, IMB=0, CT=-30.0)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0, IMB=0, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep PhaseChangers insertion loss - IL=-0.5dB IMB=0dB NEUROPULS CT=-30dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240718/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBellCrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'ClementsBell_Arct', 'FldzhyanBell_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBellCrossingSide_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240718_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0, CT=-30.0)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep PhaseChangers insertion loss - IL=-0.5dB IMB=0.5dB NEUROPULS CT=-30dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240718/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'ClementsBell_Arct', 'FldzhyanBell_Arct',
    'NEUROPULSBell_Arct', 'NEUROPULSBellCrossingSide_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240718_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0.5, CT=-30.0)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0.5, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep PhaseChangers insertion loss - IL=-0.5dB Fldzhyan IMB=-0.5dB NEUROPULS CT=-30dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240718/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBellCrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'ClementsBell_Arct', 'FldzhyanBell_Arct', 'NEUROPULSBellCrossingSide_Arct',
    'NEUROPULSBell_Arct',]

def filter_list_of_dicts(dict_list, IL, IMB, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[2] == IMB and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list

plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240718_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0.5, CT=-30.0)
    elif "Fldzhyan" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=-0.5, CT=-1000.0)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.5, IMB=0.5, CT=-1000.0)
    PC_i_loss = [sim["PC_i_loss_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(PC_i_loss, average, yerr=std_dev,
                marker='o', label=arct)
plt.xlabel('Phase Changers insertion loss [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()
