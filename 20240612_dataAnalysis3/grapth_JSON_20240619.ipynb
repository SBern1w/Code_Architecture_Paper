# %% [markdown]
# # Grapths N = 8 Fidelity

# %% [markdown]
# ## Sweep IMB - IL=0dB CT=-infdB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240619/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']


def filter_list_of_dicts(dict_list, IL, CT):
    filtered_list = []
    for dictionary in dict_list:
        if list(dictionary.values())[1] == IL and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list


plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240619_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, CT=-1000.0)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, CT=None)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=arct)
# plt.errorbar(imbalances, average, yerr=std_dev,
#             marker='o', label=name_arch)
# plt.title('TO NAME BETTER !!!!!!')
plt.xlabel('imbalanced [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep IMB - IL=-0.22dB CT=-infdB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240619/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']


def filter_list_of_dicts(dict_list, IL, CT):
    filtered_list = []
    for dictionary in dict_list:
        if round(list(dictionary.values())[1], 2) == IL and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list


plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240619_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.22, CT=-1000.0)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.22, CT=None)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=arct)
# plt.errorbar(imbalances, average, yerr=std_dev,
#             marker='o', label=name_arch)
plt.title('TO NAME BETTER !!!!!!')
plt.xlabel('imbalanced [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep IMB - IL=-0.46dB CT=-infdB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240619/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']


def filter_list_of_dicts(dict_list, IL, CT):
    filtered_list = []
    for dictionary in dict_list:
        if round(list(dictionary.values())[1], 2) == IL and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list


plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240619_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.46, CT=-1000.0)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.46, CT=None)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=arct)
# plt.errorbar(imbalances, average, yerr=std_dev,
#             marker='o', label=name_arch)
plt.title('TO NAME BETTER !!!!!!')
plt.xlabel('imbalanced [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep IMB - IL=-0.97dB CT=-infdB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240619/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']


def filter_list_of_dicts(dict_list, IL, CT):
    filtered_list = []
    for dictionary in dict_list:
        if round(list(dictionary.values())[1], 2) == IL and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
    return filtered_list


plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240619_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.97, CT=-1000.0)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.97, CT=None)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=arct)
# plt.errorbar(imbalances, average, yerr=std_dev,
#             marker='o', label=name_arch)
plt.title('TO NAME BETTER !!!!!!')
plt.xlabel('imbalanced [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep IMB - IL=0dB CT=-19.95dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240619/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']


def filter_list_of_dicts(dict_list, IL, CT):
    filtered_list = []
    for dictionary in dict_list:
        if CT==list(dictionary.values())[3] and round(list(dictionary.values())[1], 2) == IL and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
        elif CT!=list(dictionary.values())[3] and round(list(dictionary.values())[1], 2) == IL and round(list(dictionary.values())[3], 2) == CT:
            filtered_list.append(dictionary)
    return filtered_list


plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240619_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, CT=-19.96)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0.0, CT=None)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=arct)
# plt.errorbar(imbalances, average, yerr=std_dev,
#             marker='o', label=name_arch)
plt.title('TO NAME BETTER !!!!!!')
plt.xlabel('imbalanced [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep IMB - IL=-0.97dB CT=-19.95dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240619/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']


def filter_list_of_dicts(dict_list, IL, CT):
    filtered_list = []
    for dictionary in dict_list:
        if CT==list(dictionary.values())[3] and round(list(dictionary.values())[1], 2) == IL and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
        elif CT!=list(dictionary.values())[3] and round(list(dictionary.values())[1], 2) == IL and round(list(dictionary.values())[3], 2) == CT:
            filtered_list.append(dictionary)
    return filtered_list


plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240619_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.97, CT=-19.96)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.97, CT=None)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=arct)
# plt.errorbar(imbalances, average, yerr=std_dev,
#             marker='o', label=name_arch)
plt.title('TO NAME BETTER !!!!!!')
plt.xlabel('imbalanced [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep IMB - IL=0dB CT=-9.54dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240619/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']


def filter_list_of_dicts(dict_list, IL, CT):
    filtered_list = []
    for dictionary in dict_list:
        if CT==list(dictionary.values())[3] and round(list(dictionary.values())[1], 2) == IL and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
        elif CT!=list(dictionary.values())[3] and round(list(dictionary.values())[1], 2) == IL and round(list(dictionary.values())[3], 2) == CT:
            filtered_list.append(dictionary)
    return filtered_list


plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240619_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0, CT=-9.54)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=0, CT=None)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=arct)
# plt.errorbar(imbalances, average, yerr=std_dev,
#             marker='o', label=name_arch)
plt.title('TO NAME BETTER !!!!!!')
plt.xlabel('imbalanced [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sweep IMB - IL=-0.97dB CT=-9.54dB

# %%
# Create the grapth
import json
import matplotlib.pyplot as plt

JSON_folder_name = 'organized_data/20240619/'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']


def filter_list_of_dicts(dict_list, IL, CT):
    filtered_list = []
    for dictionary in dict_list:
        if CT==list(dictionary.values())[3] and round(list(dictionary.values())[1], 2) == IL and list(dictionary.values())[3] == CT:
            filtered_list.append(dictionary)
        elif CT!=list(dictionary.values())[3] and round(list(dictionary.values())[1], 2) == IL and round(list(dictionary.values())[3], 2) == CT:
            filtered_list.append(dictionary)
    return filtered_list


plt.figure(figsize=(10, 6))
# Download the file
for arct in name_models_choise:
    file_JSON = "20240619_traking_"+arct+"_N8.json"
    with open(JSON_folder_name+file_JSON, 'r') as file:
        data = json.load(file)
    simulations = data["simulations"]
    if "NEUROPULS" in arct:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.97, CT=-9.54)
    else:
        filtered_list_disct = filter_list_of_dicts(dict_list=simulations, IL=-0.97, CT=None)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=arct)
# plt.errorbar(imbalances, average, yerr=std_dev,
#             marker='o', label=name_arch)
plt.title('TO NAME BETTER !!!!!!')
plt.xlabel('imbalanced [dB]')
plt.ylabel('Fidelity')
plt.legend()
plt.grid(True)
plt.show()
