# %% [markdown]
# # Sort

# %%
# Sort the dictionary by architecture and imbalances
import json

JSON_file_name = 'goodData/20240610_traking_N8_Fidelity_sweep_imb.json'
architecture_order = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']

# Sorting function
def custom_sort_key(item):
    return (architecture_order.index(item['architecture']), item['imbalance_const'])

# Read
with open(JSON_file_name, 'r') as file:
    data = json.load(file)

simulations = data["simulations"]
# Sort the list
sorted_simulations = sorted(simulations, key=custom_sort_key)

data["simulations"] = sorted_simulations

if False:
    # Write JSON data to a file
    with open(JSON_file_name, 'w') as json_file:
        json.dump(data, json_file, indent=4)

# %% [markdown]
# # Grapths

# %% [markdown]
# ## N = 4 with Immaginary Crossing

# %%
# Create the grapth
import matplotlib.pyplot as plt

JSON_file_name = 'goodData/20240610_PROB_traking_N4_NEUROPUSL_ImCrossing_MSE_sweep_imb.json'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']

# Download the file
with open(JSON_file_name, 'r') as file:
    data = json.load(file)
simulations = data["simulations"]

def filter_list_of_dicts(dict_list, name_arch):
    filtered_list = []
    for dictionary in dict_list:
        for value in dictionary.values():
            if value == name_arch:
                filtered_list.append(dictionary)
                break  # No need to check other values in the same dictionary
    return filtered_list

plt.figure(figsize=(10, 6))
for name_arch in name_models_choise:
    filtered_list_disct = filter_list_of_dicts(simulations, name_arch)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=name_arch)
plt.title('Model Value Trends by iloss')
plt.xlabel('imbalanced')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)
plt.show()

for model in name_models:
    MSE_0 = [sim["average"] for sim in filter_list_of_dicts(simulations, model)][9]
    print(model+' average: '+str(MSE_0))
# Out:
# Clements_Arct average: 0.019678251741073235
# ClementsBell_Arct average: 0.0196485224546581
# Fldzhyan_Arct average: 0.0005511277797784189
# FldzhyanBell_Arct average: 0.0005530325268494842
# FldzhyanBellHalf_Arct average: 0.07054514805839913
# NEUROPULS_Arct average: 0.013482356141700284
# NEUROPULSCrossingSide_Arct average: 0.01332641728931983
# NEUROPULSBell_Arct average: 0.013452255057912005
# NEUROPULSBell_CrossingSide_Arct average: 0.014945654261580801
# NEUROPULSHalf_Arct average: 0.0650320111653762
# NEUROPULSBellHalf_Arct average: 0.0649083285667974
# NEUROPULSBellHalfCrossingSide_Arct average: 0.06581421205401126

# %% [markdown]
# ## N = 8

# %%
# Create the grapth
import matplotlib.pyplot as plt

JSON_file_name = 'goodData/20240610_traking_N8_NEUROPULS_ImCrossing_MSE_sweep_imb.json'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']

# Download the file
with open(JSON_file_name, 'r') as file:
    data = json.load(file)
simulations = data["simulations"]

def filter_list_of_dicts(dict_list, name_arch):
    filtered_list = []
    for dictionary in dict_list:
        for value in dictionary.values():
            if value == name_arch:
                filtered_list.append(dictionary)
                break  # No need to check other values in the same dictionary
    return filtered_list

plt.figure(figsize=(10, 6))
for name_arch in name_models_choise:
    filtered_list_disct = filter_list_of_dicts(simulations, name_arch)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=name_arch)
plt.title('Model Value Trends by iloss')
plt.xlabel('imbalanced')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)
plt.show()

for model in name_models:
    MSE_0 = [sim["average"] for sim in filter_list_of_dicts(simulations, model)][10]
    print(model+' average: '+str(MSE_0))
# Out:
# Clements_Arct average: 0.0033196356098504297
# ClementsBell_Arct average: 0.003364669741697628
# Fldzhyan_Arct average: 3.2646788978250805e-07
# FldzhyanBell_Arct average: 7.20614276368237e-08
# FldzhyanBellHalf_Arct average: 0.025004271490609846
# NEUROPULS_Arct average: 0.00030657794599007505
# NEUROPULSCrossingSide_Arct average: 0.0003122464176974257
# NEUROPULSBell_Arct average: 0.00028466489370045534
# NEUROPULSBell_CrossingSide_Arct average: 0.0009332924663126344
# NEUROPULSHalf_Arct average: 0.04174206040236836
# NEUROPULSBellHalf_Arct average: 0.0417367302546427
# NEUROPULSBellHalfCrossingSide_Arct average: 0.04211213390455455

# %% [markdown]
# # Fidelity

# %% [markdown]
# ## N = 4

# %%
# Create the grapth
import matplotlib.pyplot as plt

JSON_file_name = 'goodData/20240610_traking_N4_Fidelity_sweep_imb.json'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']

# Download the file
with open(JSON_file_name, 'r') as file:
    data = json.load(file)
simulations = data["simulations"]

def filter_list_of_dicts(dict_list, name_arch):
    filtered_list = []
    for dictionary in dict_list:
        for value in dictionary.values():
            if value == name_arch:
                filtered_list.append(dictionary)
                break  # No need to check other values in the same dictionary
    return filtered_list

plt.figure(figsize=(10, 6))
for name_arch in name_models_choise:
    filtered_list_disct = filter_list_of_dicts(simulations, name_arch)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=name_arch)
plt.title('Model Value Trends by iloss')
plt.xlabel('imbalanced')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)
plt.show()

for model in name_models:
    MSE_0 = [sim["average"] for sim in filter_list_of_dicts(simulations, model)][9]
    print(model+' average: '+str(MSE_0))
# Out:
# Clements_Arct average: 0.9999999998958945
# ClementsBell_Arct average: 0.9999999998220669
# Fldzhyan_Arct average: 0.9999822647671927
# FldzhyanBell_Arct average: 0.9999815405539387
# FldzhyanBellHalf_Arct average: 0.8115938597358587
# NEUROPULS_Arct average: 0.9999999987964033
# NEUROPULSCrossingSide_Arct average: 0.99999999924399
# NEUROPULSBell_Arct average: 0.9999999995651596
# NEUROPULSBell_CrossingSide_Arct average: 0.9822293419304746
# NEUROPULSHalf_Arct average: 0.7975839755194607
# NEUROPULSBellHalf_Arct average: 0.7977710889005964
# NEUROPULSBellHalfCrossingSide_Arct average: 0.7851323593725147

# %% [markdown]
# ## N = 8

# %%
# Create the grapth
import matplotlib.pyplot as plt

JSON_file_name = 'goodData/20240610_traking_N8_Fidelity_sweep_imb.json'
name_models = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']
name_models_choise = [
    'Clements_Arct', 'ClementsBell_Arct', 'Fldzhyan_Arct', 'FldzhyanBell_Arct',
    'FldzhyanBellHalf_Arct',
    'NEUROPULS_Arct', 'NEUROPULSCrossingSide_Arct', 'NEUROPULSBell_Arct', 'NEUROPULSBell_CrossingSide_Arct',
    'NEUROPULSHalf_Arct', 'NEUROPULSBellHalf_Arct', 'NEUROPULSBellHalfCrossingSide_Arct']

# Download the file
with open(JSON_file_name, 'r') as file:
    data = json.load(file)
simulations = data["simulations"]

def filter_list_of_dicts(dict_list, name_arch):
    filtered_list = []
    for dictionary in dict_list:
        for value in dictionary.values():
            if value == name_arch:
                filtered_list.append(dictionary)
                break  # No need to check other values in the same dictionary
    return filtered_list

plt.figure(figsize=(10, 6))
for name_arch in name_models_choise:
    filtered_list_disct = filter_list_of_dicts(simulations, name_arch)
    imbalances = [sim["imbalance_const"] for sim in filtered_list_disct]
    average = [sim["average"] for sim in filtered_list_disct]
    std_dev = [sim["std_dev"] for sim in filtered_list_disct]
    plt.errorbar(imbalances, average, yerr=std_dev,
                marker='o', label=name_arch)
plt.title('Model Value Trends by iloss')
plt.xlabel('imbalanced')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)
plt.show()

for model in name_models:
    MSE_0 = [sim["average"] for sim in filter_list_of_dicts(simulations, model)][9]
    print(model+' average: '+str(MSE_0))
# Out:
# Clements_Arct average: 0.9999999457085003
# ClementsBell_Arct average: 0.9999998882814345
# Fldzhyan_Arct average: 0.9999727632907556
# FldzhyanBell_Arct average: 0.9999770898759792
# FldzhyanBellHalf_Arct average: 0.7429650023182813
# NEUROPULS_Arct average: 0.9999978780274402
# NEUROPULSCrossingSide_Arct average: 0.9999910788978021
# NEUROPULSBell_Arct average: 0.9999990161045063
# NEUROPULSBell_CrossingSide_Arct average: 0.9974767151406116
# NEUROPULSHalf_Arct average: 0.7086202846496188
# NEUROPULSBellHalf_Arct average: 0.7086560796580396
# NEUROPULSBellHalfCrossingSide_Arct average: 0.7035896301333145

# %% [markdown]
# ## N
